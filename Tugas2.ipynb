# %%
print("===================================Soal1=====================================")
print("")
print("==== s2 ====")
a = 0
b = 1
c = 4
d = 7
e = 5
f = 0

hasil = (a + b + c + d + e + f )
print(hasil, 'orang')

print("==== s1 ====")
a = 4
b = 12
c = 6
d = 13
e = 14
f = 0

hasil = (a + b + c + d + e + f )
print(hasil, 'orang')

print("==== Tamat SMA ====")
a = 12
b = 17
c = 5
d = 20
e = 11
f = 75

hasil = (a + b + c + d + e + f )
print(hasil, 'orang')

print("==== Tamat SMP ====")
a = 5
b = 6
c = 15
d = 9
e = 20
f = 15

hasil = (a + b + c + d + e + f )
print(hasil , 'orang')

print("==== Tamat SD ====")
a = 1
b = 8
c = 0
d = 19
e = 10
f = 1

hasil = (a + b + c + d + e + f )
print(hasil, 'orang')

print("==== Tidak Diketahui ====")
a = 2
b = 14
c = 3
d = 10
e = 0
f = 1

hasil = (a + b + c + d + e + f )
print(hasil, 'orang')

print("")
print("==========================Soal2========================================")
print("")
print("===s2===")
a = 17
b = 0.25
jml = (a*b)
print("Maka mutunya adalah : " + str(jml))

print("===s1===")
a = 49
b = 0.20
jml = (a*b)
print("Maka mutunya adalah : " + str(jml))

print("===Tamat SMA===")
a = 140
b = 0.15
jml = (a*b)
print("Maka mutunya adalah : " + str(jml))

print("===Tamat SMP===")
a = 70
b = 0.10
jml = (a*b)
print("Maka mutunya adalah : " + str(jml))

print("===SD===")
a = 39
b = 0.05
jml = (a*b)
print("Maka mutunya adalah : " + str(jml))

print("===tidak diketahui===")
a = 30
b = 0.03
jml = (a*b)
print("Maka mutunya adalah : " + str(jml))

print("")
print("=============================================Soal3===============================")
print("")
print("umur >70")
print("=================1==================")
s2_a = 0
s2_b = 0.25
hasil_s2 = (s2_a * s2_b)
print("Maka mutu dari s2 adalah :" +str(hasil_s2))
s1_c = 4
s1_d = 0.20
hasil_s1 = (s1_c * s1_d)
print("Maka mutu dari s1 adalah :" +str(hasil_s1))
sma_e = 12
sma_f = 0.15
hasil_sma = (sma_e * sma_f)
print("Maka mutu dari sma adalah :" +str(hasil_sma))
smp_g = 5
smp_h = 0.10
hasil_smp = (smp_g * smp_h)
print("Maka mutu dari smp adalah :" +str(hasil_smp))
sd_i = 1
sd_j = 0.05
hasil_sd = (sd_i * sd_j)
print("Maka mutu dari sd adalah :" +str(hasil_sd))
td_k = 2
td_l = 0.03
hasil_td = (td_k * td_l)
print("Maka mutu dari tdk adalah :" +str(hasil_td))
print("")
hasil = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td)
print("maka mutualisalinya adalah : " + str(hasil))
print("")

print("umur >60")
print("")
print("=================2==================")
s2_a = 1
s2_b = 0.25
hasil_s2 = (s2_a * s2_b)
print("Maka mutu dari s2 adalah :" +str(hasil_s2))
s1_c = 12
s1_d = 0.20
hasil_s1 = (s1_c * s1_d)
print("Maka mutu dari s1 adalah :" +str(hasil_s1))
sma_e = 17
sma_f = 0.15
hasil_sma = (sma_e * sma_f)
print("Maka mutu dari sma adalah :" +str(hasil_sma))
smp_g = 6
smp_h = 0.10
hasil_smp = (smp_g * smp_h)
print("Maka mutu dari smp adalah :" +str(hasil_smp))
sd_i = 8
sd_j = 0.05
hasil_sd = (sd_i * sd_j)
print("Maka mutu dari sd adalah :" +str(hasil_sd))
td_k = 14
td_l = 0.03
hasil_td = (td_k * td_l)
print("Maka mutu dari tdk adalah :" +str(hasil_td))
print("")
hasil = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td)
print("maka mutualisalinya adalah : " + str(hasil))
print("")

print("umur >50")
print("")
print("=================3==================")
s2_a = 4
s2_b = 0.25
hasil_s2 = (s2_a * s2_b)
print("Maka mutu dari s2 adalah :" +str(hasil_s2))
s1_c = 6
s1_d = 0.20
hasil_s1 = (s1_c * s1_d)
print("Maka mutu dari s1 adalah :" +str(hasil_s1))
sma_e = 5
sma_f = 0.15
hasil_sma = (sma_e * sma_f)
print("Maka mutu dari sma adalah :" +str(hasil_sma))
smp_g = 15
smp_h = 0.10
hasil_smp = (smp_g * smp_h)
print("Maka mutu dari smp adalah :" +str(hasil_smp))
sd_i = 0
sd_j = 0.05
hasil_sd = (sd_i * sd_j)
print("Maka mutu dari sd adalah :" +str(hasil_sd))
td_k = 3
td_l = 0.03
hasil_td = (td_k * td_l)
print("Maka mutu dari tdk adalah :" +str(hasil_td))
print("")
hasil = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td)
print("maka mutualisalinya adalah : " + str(hasil))
print("")

print("umur >40")
print("")
print("=================4==================")
s2_a = 7
s2_b = 0.25
hasil_s2 = (s2_a * s2_b)
print("Maka mutu dari s2 adalah :" +str(hasil_s2))
s1_c = 13
s1_d = 0.20
hasil_s1 = (s1_c * s1_d)
print("Maka mutu dari s1 adalah :" +str(hasil_s1))
sma_e = 20
sma_f = 0.15
hasil_sma = (sma_e * sma_f)
print("Maka mutu dari sma adalah :" +str(hasil_sma))
smp_g = 9
smp_h = 0.10
hasil_smp = (smp_g * smp_h)
print("Maka mutu dari smp adalah :" +str(hasil_smp))
sd_i = 19
sd_j = 0.05
hasil_sd = (sd_i * sd_j)
print("Maka mutu dari sd adalah :" +str(hasil_sd))
td_k = 10
td_l = 0.03
hasil_td = (td_k * td_l)
print("Maka mutu dari tdk adalah :" +str(hasil_td))
print("")
hasil = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td)
print("maka mutualisalinya adalah : " + str(hasil))
print("")

print("umur >30")
print("")
print("=================5==================")
s2_a = 5
s2_b = 0.25
hasil_s2 = (s2_a * s2_b)
print("Maka mutu dari s2 adalah :" +str(hasil_s2))
s1_c = 14
s1_d = 0.20
hasil_s1 = (s1_c * s1_d)
print("Maka mutu dari s1 adalah :" +str(hasil_s1))
sma_e = 11
sma_f = 0.15
hasil_sma = (sma_e * sma_f)
print("Maka mutu dari sma adalah :" +str(hasil_sma))
smp_g = 20
smp_h = 0.10
hasil_smp = (smp_g * smp_h)
print("Maka mutu dari smp adalah :" +str(hasil_smp))
sd_i = 10
sd_j = 0.05
hasil_sd = (sd_i * sd_j)
print("Maka mutu dari sd adalah :" +str(hasil_sd))
td_k = 0
td_l = 0.03
hasil_td = (td_k * td_l)
print("Maka mutu dari tdk adalah :" +str(hasil_td))
print("")
hasil = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td)
print("maka mutualisalinya adalah : " + str(hasil))
print("")

print("umur >20")
print("")
print("=================6==================")
s2_a = 0
s2_b = 0.25
hasil_s2 = (s2_a * s2_b)
print("Maka mutu dari s2 adalah :" +str(hasil_s2))
s1_c = 0
s1_d = 0.20
hasil_s1 = (s1_c * s1_d)
print("Maka mutu dari s1 adalah :" +str(hasil_s1))
sma_e = 75
sma_f = 0.15
hasil_sma = (sma_e * sma_f)
print("Maka mutu dari sma adalah :" +str(hasil_sma))
smp_g = 15
smp_h = 0.10
hasil_smp = (smp_g * smp_h)
print("Maka mutu dari smp adalah :" +str(hasil_smp))
sd_i = 1
sd_j = 0.05
hasil_sd = (sd_i * sd_j)
print("Maka mutu dari sd adalah :" +str(hasil_sd))
td_k = 1
td_l = 0.03
hasil_td = (td_k * td_l)
print("Maka mutu dari tdk adalah :" +str(hasil_td))
print("")
hasil = (hasil_s2 + hasil_s1 + hasil_sma + hasil_smp + hasil_sd + hasil_td)
print("maka bobot indexsmutualisalinya adalah : " + str(hasil))
print("")
# Out:
# ===================================Soal1=====================================
#
# ==== s2 ====
# 17 orang
# ==== s1 ====
# 49 orang
# ==== Tamat SMA ====
# 140 orang
# ==== Tamat SMP ====
# 70 orang
# ==== Tamat SD ====
# 39 orang
# ==== Tidak Diketahui ====
# 30 orang
#
# ==========================Soal2========================================
#
# ===s2===
# Maka mutunya adalah : 4.25
# ===s1===
# Maka mutunya adalah : 9.8
# ===Tamat SMA===
# Maka mutunya adalah : 21.0
# ===Tamat SMP===
# Maka mutunya adalah : 7.0
# ===SD===
# Maka mutunya adalah : 1.9500000000000002
# ===tidak diketahui===
# Maka mutunya adalah : 0.8999999999999999
#
# =============================================Soal3===============================
#
# umur >70
# =================1==================
# Maka mutu dari s2 adalah :0.0
# Maka mutu dari s1 adalah :0.8
# Maka mutu dari sma adalah :1.7999999999999998
# Maka mutu dari smp adalah :0.5
# Maka mutu dari sd adalah :0.05
# Maka mutu dari tdk adalah :0.06
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
#cara menampilkan grafik bar
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['s2', 's1', 'sma', 'smp', 'sd', 'tdk']
hasil = [17, 49, 140,  70,  39, 30]
c = 'red','blue', 'orange'
plt.title("Pendidikan")
ax.bar(pendidikan, hasil, color = c)
plt.show()

#usia
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = [70, 60, 50, 40, 30, 20]
hasil = [3.20, 6.62, 4.54, 9.5, 8.20,  12.83]
c = 'red','blue', 'orange'
plt.title("usia")
ax.bar(pendidikan, hasil, color = c)
plt.show()

# %%
#pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis ('equal')
plt.title("Pendidikan")
pendidikan = ['s2', 's1', 'sma', 'smp', 'sd', 'tdk']
hasil = [17, 49, 140,  70,  39, 30]
ax.pie(hasil,labels=pendidikan,autopct='%1.2f%%')
plt.show()

#umur
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis ('equal')
plt.title("umur")
pendidikan = [70, 60, 50, 40, 30, 20]
hasil = [3.20, 6.62, 4.54, 9.5, 8.20,  12.83]
ax.pie(hasil,labels=pendidikan,autopct='%1.2f%%')
plt.show()

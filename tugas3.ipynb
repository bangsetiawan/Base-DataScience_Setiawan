# %%
import matplotlib.pyplot as plt

# %%
#Eskul klas 10 soal no1
print("=======================Soal1")
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
hasil = [5, 18, 30,  7,  16, 19, 12]
c = 'red','blue', 'orange'
plt.title("Ekskul klas 10")
ax.bar(pendidikan, hasil, color = c)
plt.show()
# Out:
# =======================Soal1

# %%
#menghitung jumlah siswa soal no2
a = 5
b = 21
c = 6

hasil = ( a + b ) + (c)
print("mengikuti Paskibra = " + str(hasil))

a = 18
b = 4
c = 12

hasil = ( a + b ) + (c)
print("mengikuti PMR = " + str(hasil))

a = 30
b = 8
c = 24

hasil = ( a + b ) + (c)
print("mengikuti Pramuka = " + str(hasil))

a = 7
b = 29
c = 15

hasil = ( a + b ) + (c)
print("mengikuti futsal = " + str(hasil))

a = 16
b = 10
c = 12

hasil = ( a + b ) + (c)
print("mengikuti Volly = " + str(hasil))

a = 19
b = 18
c = 4

hasil = ( a + b ) + (c)
print("mengikuti Kesenian = " + str(hasil))

a = 12
b = 10
c = 7

hasil = ( a + b ) + (c)
print("mengikuti Rohis = " + str(hasil))

#diagram batang
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
hasil = [32, 34, 62, 51, 38, 41, 29]
c = 'red','blue', 'orange'
plt.title("Ekskul klas 10")
ax.bar(pendidikan, hasil, color = c)
plt.show()
# Out:
# mengikuti Paskibra = 32
# mengikuti PMR = 34
# mengikuti Pramuka = 62
# mengikuti futsal = 51
# mengikuti Volly = 38
# mengikuti Kesenian = 41
# mengikuti Rohis = 29

# %%
#soal no 3
a = 7
b = 29
c = 15

hasil_f = (a + b) + (c)
print("futsl = " + str(hasil_f))

a = 16
b = 10
c = 12

hasil_v = (a + b) + (c)
print("volly = " + str(hasil_v))
print("")

jumlah = (hasil_f + hasil_v)
print("hasil olahraga = " + str(jumlah))
print("")

a = 5
b = 21
c = 6

hasil_pa = ( a + b ) + (c)
print("mengikuti Paskibra = " + str(hasil_pa))

a = 18
b = 4
c = 12

hasil_pm = ( a + b ) + (c)
print("mengikuti PMR = " + str(hasil_pm))

a = 30
b = 8
c = 24

hasil_pr= ( a + b ) + (c)
print("mengikuti Pramuka = " + str(hasil_pr))

a = 19
b = 18
c = 4

hasil_k = ( a + b ) + (c)
print("mengikuti Kesenian = " + str(hasil_k))

a = 12
b = 10
c = 7

hasil_r = ( a + b ) + (c)
print("mengikuti Rohis = " + str(hasil_r))
print("")

jumlah = (hasil_pa + hasil_pr) + (hasil_pr + hasil_k) + (hasil_k)
print("hasil mengikuti = " + str(jumlah))
print("")

a = 17
b = 8
c = 20

hasil_td = (a + b) + (c)
print("yang tidak mengikuti = " + str (hasil_td))

print("========Diagram batang============")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ekskul = ['olahraga', 'mengikuti', 'tidak mengikuti']
jumlah = [89, 238, 45]
c = 'red','blue', 'orange'
plt.title("jumlah siswa")
ax.bar(ekskul, jumlah, color = c)
plt.show()
print("")

print("========Diagram pie chatr============")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis ('equal')
plt.title("jumlah Siswa")
ekskul = ['olahraga', 'mengikuti', 'tidak mengikuti']
jumlah = [89, 238, 45]
ax.pie(jumlah,labels=ekskul,autopct='%1.2f%%')
plt.show()
# Out:
# futsl = 51
# volly = 38
#
# hasil olahraga = 89
#
# mengikuti Paskibra = 32
# mengikuti PMR = 34
# mengikuti Pramuka = 62
# mengikuti Kesenian = 41
# mengikuti Rohis = 29
#
# hasil mengikuti = 238
#
# yang tidak mengikuti = 45
# ========Diagram batang============
# ========Diagram pie chatr============

# %%
a = 17
b = 8
c = 20
hasil_a = a/45
hasil_b = b/45
hasil_c = c/45
hasil_td = (a + b) + (c)
print("yang tidak mengikuti = " + str (hasil_td))
print("")
print("hasilnya A = " + str(hasil_a))
print("hasilnya B = " + str(hasil_b))
print("hasilnya C = " + str(hasil_c))
print("")

print("========Diagram pie chatr============")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis ('equal')
plt.title("Data yang tidak mengikuti ekskul")
ekskul = ['Kelas 10', 'Kelas 11', 'Kelas 12']
jumlah = [37, 17, 44]
ax.pie(jumlah,labels=ekskul,autopct='%1.2f%%')
plt.show()
# Out:
# yang tidak mengikuti = 45
#
# hasilnya A = 0.37777777777777777
# hasilnya B = 0.17777777777777778
# hasilnya C = 0.4444444444444444
#
# ========Diagram pie chatr============

# %%
print("=======================soal 5======================")
print("")
print("=============Diagram Batang======================")
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ekskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
jumlah = [5, 18, 30,  7,  16, 19, 12]
c = 'red','blue', 'orange'
plt.title("Ekskul klas 10")
ax.bar(ekskul, jumlah, color = c)
plt.show()
print("")
print("========Diagram pie chatr============")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis ('equal')
plt.title("Ekskul klas 10")
ekskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
jumlah = [5, 18, 30,  7,  16, 19, 12]
ax.pie(jumlah,labels=ekskul,autopct='%1.2f%%')
plt.show()
print("")

print("=2=")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ekskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
jumlah = [21, 4, 8, 29, 10, 18, 10]
c = 'red','blue', 'orange'
plt.title("Ekskul klas 11")
ax.bar(ekskul, jumlah, color = c)
plt.show()
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis ('equal')
plt.title("Ekskul klas 11")
ekskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
jumlah = [21, 4, 8, 29, 10, 18, 10]
ax.pie(jumlah,labels=ekskul,autopct='%1.2f%%')
plt.show()
print("")


print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ekskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
jumlah = [6, 12, 24, 15, 12, 4, 7]
c = 'red','blue', 'orange'
plt.title("Ekskul klas 12")
ax.bar(ekskul, jumlah, color = c)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis ('equal')
plt.title("Ekskul klas 12")
ekskul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
jumlah = [6, 12, 24, 15, 12, 4, 7]
ax.pie(jumlah,labels=ekskul,autopct='%1.2f%%')
plt.show()
print("")
# Out:
# =======================soal 5======================
#
# =============Diagram Batang======================
# ========Diagram pie chatr============
# =2=
